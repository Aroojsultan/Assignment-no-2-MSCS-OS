# %% [markdown]
#                 Chapter no 4
#             Exercise no 4.11 & 4.13
# 4-11. My Pizzas, Your Pizzas: Start with your program from Exercise 4-1
# (page 60). Make a copy of the list of pizzas, and call it friend_pizzas.
# Then, do the following:
# •	 Add a new pizza to the original list.
# •	 Add a different pizza to the list friend_pizzas.
# •	 Prove that you have two separate lists. Print the message, My favorite
# pizzas are:, and then use a for loop to print the first list. Print the message,
# My friend’s favorite pizzas are:, and then use a for loop to print the second list. Make sure each new pizza is stored in the appropriate list

# %%
print("\n\t%%%This is pizza program(4.11) %%%\n")
mypizzas_arooj=['Peproni', 'BBQ', 'Veggie']
friend_pizzas_arooj= mypizzas_arooj[:]
print(mypizzas_arooj)
print(friend_pizzas_arooj)
mypizzas_arooj.append('Supreme')
friend_pizzas_arooj.append('Tikka')
print("New list of mypizza is:", mypizzas_arooj)
print("New list of friend pizza is:", friend_pizzas_arooj)
print("\n My favourite pizzas are:")
for pizzas in mypizzas_arooj:
  print(pizzas)
print("\n My friend's favourite pizzas are:")
for pizzas in friend_pizzas_arooj:
 print(pizzas )
# Out:
# 	%%%This is pizza program(4.11) %%%
#
# ['Peproni', 'BBQ', 'Veggie']
# ['Peproni', 'BBQ', 'Veggie']
# New list of mypizza is: ['Peproni', 'BBQ', 'Veggie', 'Supreme']
# New list of friend pizza is: ['Peproni', 'BBQ', 'Veggie', 'Tikka']
#
#  My favourite pizzas are:
# Peproni
# BBQ
# Veggie
# Supreme
#
#  My friend's favourite pizzas are:
# Peproni
# BBQ
# Veggie
# Tikka

# %% [markdown]
# 4-13. Buffet: A buffet-style restaurant offers only five basic foods. Think of five
# simple foods, and store them in a tuple.
# • Use a for loop to print each food the restaurant offers.
# •Try to modify one of the items, and make sure that Python rejects the
# change.
# •The restaurant changes its menu, replacing two of the items with different
# foods. Add a block of code that rewrites the tuple, and then use a for
# loop to print each of the items on the revised menu.

# %%
print("\n\t%%%This is buffet resturant program(4.13) %%%\n")
resturant_arooj=('biryani', 'fries', 'manchurian', 'Iazaniya', 'soup') 
for foods in resturant_arooj:
   print(foods.title())
#resturant_arooj[0]='Coke'
print("\n As we cann't modified list in tuple so I will intialize the list with new value.\n")
resturant_arooj = ('sandwich', 'fries', 'manchurian', 'burger', 'soup')
print("\n Modified list of food is:\n")  
for foods in resturant_arooj:     
   print( foods. title())
# Out:
# 	%%%This is buffet resturant program(4.13) %%%
#
# Biryani
# Fries
# Manchurian
# Iazaniya
# Soup
#
#  As we cann't modified list in tuple so I will intialize the list with new value.
#
#
#  Modified list of food is:
#
# Sandwich
# Fries
# Manchurian
# Burger
# Soup
